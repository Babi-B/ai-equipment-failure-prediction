# %%
# Load Data
import pandas as pd
from utils.preprocess import load_nasa_data
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 3
#       1 # Load Data
#       2 import pandas as pd
# ----> 3 from utils import preprocess
#
# ModuleNotFoundError: No module named 'utils'

# %%
train_df = preprocess.load_nasa_data(['data/train_FD001.txt', 'data/train_FD002.txt', 'data/train_FD003.txt', 'data/train_FD004.txt'])
train_df = handle_missing_data(train_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 train_df = preprocess.load_nasa_data(['data/train_FD001.txt', 'data/train_FD002.txt', 'data/train_FD003.txt', 'data/train_FD004.txt'])
#       2 train_df = handle_missing_data(train_df)
#
# NameError: name 'preprocess' is not defined

# %%
# Cell 2: Metadata Analysis
train_df[['dataset_id', 'operating_condition', 'fault_mode']].value_counts().plot(kind='barh')
# Out:
#                  0             1             2             3        4   \
# count  20631.000000  20631.000000  20631.000000  20631.000000  20631.0
# mean      51.506568    108.807862     -0.000009      0.000002    100.0
# std       29.227633     68.880990      0.002187      0.000293      0.0
# min        1.000000      1.000000     -0.008700     -0.000600    100.0
# 25%       26.000000     52.000000     -0.001500     -0.000200    100.0
# 50%       52.000000    104.000000      0.000000      0.000000    100.0
# 75%       77.000000    156.000000      0.001500      0.000300    100.0
# max      100.000000    362.000000      0.008700      0.000600    100.0
#
#              5             6             7             8             9   ...  \
# count  20631.00  20631.000000  20631.000000  20631.000000  2.063100e+04  ...
# mean     518.67    642.680934   1590.523119   1408.933782  1.462000e+01  ...
# std        0.00      0.500053      6.131150      9.000605  1.776400e-15  ...
# ...

# %%
# Cell 3: Sensor Trends
import seaborn as sns
sns.lineplot(x='cycle', y='sensor_7', hue='fault_mode', data=train_df[train_df['engine_id'] == 1])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 3
#       1 # Assign column names (replace with your dataset's actual columns)
#       2 columns = ['id', 'cycle', 'setting1', 'setting2', 'setting3'] + [f'sensor_{i}' for i in range(1, 22)]
# ----> 3 train_data.columns = columns
#       4 train_data
#
# File ~\Desktop\SCHOOL\LAST_YEAR\SECOND_SEMESTER\ai-equipment-failure-prediction\.venv\Lib\site-packages\pandas\core\generic.py:6313, in NDFrame.__setattr__(self, name, value)
#    6311 try:
#    6312     object.__getattribute__(self, name)
# -> 6313     return object.__setattr__(self, name, value)
#    6314 except AttributeError:
#    6315     pass
#
# File properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# ...
